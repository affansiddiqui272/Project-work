# %% [markdown]
# # ***ANNUAL TEMPRTURE***
#
# >

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/annual_temp.csv')
print(data.head())
# Out:
#     Source  Year    Mean
# 0     GCAG  2015  0.8990
# 1  GISTEMP  2015  0.8700
# 2     GCAG  2014  0.7402
# 3  GISTEMP  2014  0.7500
# 4     GCAG  2013  0.6687

# %%
X_A = data[['Year']]
y_A = data['Year']

# %%
model_A = LinearRegression()
model_A.fit(X_A, y_A)
# Out:
# LinearRegression()

# %%
X_B = data[['Year']]
y_B = data['Source']

# %%
model_B = LinearRegression()

# %%
print("Predictions for Industry A:")
for year, prediction in zip(future_years.flatten(), predictions_A):
    print(f"Predicted temperature for {year}: {prediction:.2f}")
# Out:
# Predictions for Industry A:
# Predicted temperature for 2016: 2016.00
# Predicted temperature for 2017: 2017.00

# %%
plt.figure(figsize=(12, 6))
plt.plot(data['Year'], marker='o', label='Industry A Historical')
plt.plot(data['Year'], marker='x', label='Industry B Historical')
plt.plot(future_years, predictions_A, 'ro', label='Industry A Predictions')
plt.plot(future_years,'rx')
plt.title('Annual Temperature Predictions for Industry A and B')
plt.xlabel('Year')
plt.ylabel('Temperature')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(data['Year'], marker='o', label='Industry A')
plt.plot(data['Year'], marker='x', label='Industry B')
plt.title('Annual Temperature for Industry A and B')
plt.xlabel('Year')
plt.ylabel('Temperature')
plt.legend()
plt.grid()
plt.show()
